# %%
import pandas as pd

# %%
df = pd.read_csv("Medicare_Physician_and_Other_Supplier_National_Provider_Identifier__NPI__Aggregate_Report__Calendar_Year_2014.csv")
# Out:
# C:\Users\Vignesh\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head()
# Out:
#    National Provider Identifier Last Name/Organization Name of the Provider  \
# 0                    1659374411                                        MAHR
# 1                    1073738571                                        GIBB
# 2                    1619972387                                        DEEM
# 3                    1265649073                                      GAMBLE
# 4                    1366640377                                       DIRKS
#
#   First Name of the Provider Middle Initial of the Provider  \
# 0                       TODD                              A
# 1                      JOYCE                              E
# 2                     ROBERT                              B
# 3                      SARAH                              M
# 4                    ZACHARY                              B
#
#   Credentials of the Provider Gender of the Provider  \
# 0                          MD                      M
# ...

# %%
len(df)
# Out:
# 986677

# %%
df.columns
# Out:
# Index(['National Provider Identifier',
#        'Last Name/Organization Name of the Provider',
#        'First Name of the Provider', 'Middle Initial of the Provider',
#        'Credentials of the Provider', 'Gender of the Provider',
#        'Entity Type of the Provider', 'Street Address 1 of the Provider',
#        'Street Address 2 of the Provider', 'City of the Provider',
#        'Zip Code of the Provider', 'State Code of the Provider',
#        'Country Code of the Provider', 'Provider Type of the Provider',
#        'Medicare Participation Indicator', 'Number of HCPCS',
#        'Number of Services', 'Number of Medicare Beneficiaries',
#        'Total Submitted Charge Amount', 'Total Medicare Allowed Amount',
#        'Total Medicare Payment Amount',
#        'Total Medicare Standardized Payment Amount', 'Drug Suppress Indicator',
#        'Number of HCPCS Associated With Drug Services',
#        'Number of Drug Services',
# ...

# %%
li = df["Provider Type of the Provider"].unique()

# %%
print(li)
# Out:
# ['Allergy/Immunology' 'Nurse Practitioner' 'Family Practice'
#  'Internal Medicine' 'Optometry' 'Physician Assistant' 'Psychiatry'
#  'Orthopedic Surgery' 'Obstetrics/Gynecology' 'Pediatric Medicine'
#  'Urology' 'Radiation Oncology' 'Physical Therapist' 'Podiatry'
#  'Dermatology' 'Emergency Medicine' 'General Practice' 'Neurology'
#  'General Surgery' 'Rheumatology' 'Chiropractic' 'Otolaryngology'
#  'Infectious Disease' 'Endocrinology' 'Centralized Flu' 'Ophthalmology'
#  'Anesthesiology' 'Cardiology' 'Maxillofacial Surgery'
#  'Hematology/Oncology' 'Diagnostic Radiology' 'Gastroenterology' 'CRNA'
#  'Plastic and Reconstructive Surgery'
#  'Physical Medicine and Rehabilitation' 'Sports Medicine'
#  'Licensed Clinical Social Worker' 'Pathology'
#  'Mass Immunization Roster Biller' 'Addiction Medicine' 'Pain Management'
#  'Independent Diagnostic Testing Facility' 'Clinical Psychologist'
#  'Certified Nurse Midwife' 'Pulmonary Disease' 'Gynecological/Oncology'
# ...

# %%
print("Cardiologists" in li)
# Out:
# False

# %%
df.loc[df['Provider Type of the Provider'] == "Allergy/Immunology", ['Provider Type of the Provider']] = "Allergists"

# %%
df.loc[df['Provider Type of the Provider'] == "Endocrinology", ['Provider Type of the Provider']] = "Endocrinologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Gastroenterology", ['Provider Type of the Provider']] = "Gastroenterologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Nephrology", ['Provider Type of the Provider']] = "Nephrologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Urology", ['Provider Type of the Provider']] = "Urologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Pulmonary Disease", ['Provider Type of the Provider']] = "Pulmonologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Otolaryngology", ['Provider Type of the Provider']] = "Otolaryngologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Neurology", ['Provider Type of the Provider']] = "Neurologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Neurosurgery", ['Provider Type of the Provider']] = "Neurologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Psychiatry", ['Provider Type of the Provider']] = "Psychiatrists"

# %%
df.loc[df['Provider Type of the Provider'] == "Clinical Psychologist", ['Provider Type of the Provider']] = "Psychiatrists"

# %%
df.loc[df['Provider Type of the Provider'] == "Hematology/Oncology", ['Provider Type of the Provider']] = "Oncologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Medical Oncology", ['Provider Type of the Provider']] = "Oncologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Gynecological/Oncology", ['Provider Type of the Provider']] = "Oncologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Diagnostic Radiology", ['Provider Type of the Provider']] = "Radiologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Interventional Radiology", ['Provider Type of the Provider']] = "Radiologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Rheumatology", ['Provider Type of the Provider']] = "Rheumatologists"

# %%
df.loc[df['Provider Type of the Provider'] == "General Surgery", ['Provider Type of the Provider']] = "General surgeons"

# %%
df.loc[df['Provider Type of the Provider'] == "Plastic and Reconstructive Surgery", ['Provider Type of the Provider']] = "Orthopedic surgeons"

# %%
df.loc[df['Provider Type of the Provider'] == "Cardiac Surgery", ['Provider Type of the Provider']] = "Cardiac surgeons"

# %%
df.loc[df['Provider Type of the Provider'] == "Maxillofacial Surgery", ['Provider Type of the Provider']] = "Oral and maxillofacial surgeons"

# %%
df.loc[df['Provider Type of the Provider'] == "Obstetrics/Gynecology", ['Provider Type of the Provider']] = "Gynecologist"

# %%
df.loc[df['Provider Type of the Provider'] == "Pediatric Medicine", ['Provider Type of the Provider']] = "Pediatrician"

# %%
df.loc[df['Provider Type of the Provider'] == "Anesthesiology", ['Provider Type of the Provider']] = "Anesthesiologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Anesthesiologist Assistants", ['Provider Type of the Provider']] = "Anesthesiologists"

# %%
df.loc[df['Provider Type of the Provider'] == "Podiatry", ['Provider Type of the Provider']] = "Podiatrist"

# %%
df.loc[df['Provider Type of the Provider'] == "Registered Dietician/Nutrition Professional", ['Provider Type of the Provider']] = "Bariatrician"

# %%
li_specialty = ['Allergists', 'Endocrinologists', 'Gastroenterologists', 'Nephrologists', 'Urologists', 'Pulmonologists', 'Otolaryngologists', 'Neurologists', 'Neurologists', 'Psychiatrists', 'Psychiatrists', 'Oncologists', 'Oncologists', 'Oncologists', 'Radiologists', 'Radiologists', 'Rheumatologists', 'General surgeons', 'Orthopedic surgeons', 'Cardiac surgeons', 'Oral and maxillofacial surgeons', 'Gynecologist', 'Pediatrician', 'Anesthesiologists', 'Anesthesiologists', 'Podiatrist', 'Bariatrician']

# %%
li_specialty = list(set(li_specialty))

# %%
print(li_specialty)
# Out:
# ['Endocrinologists', 'Neurologists', 'General surgeons', 'Orthopedic surgeons', 'Bariatrician', 'Pulmonologists', 'Psychiatrists', 'Gynecologist', 'Allergists', 'Urologists', 'Cardiac surgeons', 'Nephrologists', 'Otolaryngologists', 'Oncologists', 'Anesthesiologists', 'Podiatrist', 'Oral and maxillofacial surgeons', 'Radiologists', 'Rheumatologists', 'Pediatrician', 'Gastroenterologists']

# %%
li = df["Provider Type of the Provider"].unique()

# %%
print(li)
# Out:
# ['Allergists' 'Nurse Practitioner' 'Family Practice' 'Internal Medicine'
#  'Optometry' 'Physician Assistant' 'Psychiatrists' 'Orthopedic Surgery'
#  'Gynecologist' 'Pediatrician' 'Urologists' 'Radiation Oncology'
#  'Physical Therapist' 'Podiatrist' 'Dermatology' 'Emergency Medicine'
#  'General Practice' 'Neurologists' 'General surgeons' 'Rheumatologists'
#  'Chiropractic' 'Otolaryngologists' 'Infectious Disease'
#  'Endocrinologists' 'Centralized Flu' 'Ophthalmology' 'Anesthesiologists'
#  'Cardiology' 'Oral and maxillofacial surgeons' 'Oncologists'
#  'Radiologists' 'Gastroenterologists' 'CRNA' 'Orthopedic surgeons'
#  'Physical Medicine and Rehabilitation' 'Sports Medicine'
#  'Licensed Clinical Social Worker' 'Pathology'
#  'Mass Immunization Roster Biller' 'Addiction Medicine' 'Pain Management'
#  'Independent Diagnostic Testing Facility' 'Certified Nurse Midwife'
#  'Pulmonologists' 'Vascular Surgery' 'Certified Clinical Nurse Specialist'
# ...

# %%
df.drop(df[df['Age'] < 25].index, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Age'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-40-ed326e02272e> in <module>
# ----> 1 df.drop(df[df['Age'] < 25].index, inplace = True)
# ...

# %%
for i in li:
    if i not in li_specialty:
        df.drop(df[df["Provider Type of the Provider"] == i].index, inplace = True)

# %%
df
# Out:
#         National Provider Identifier  \
# 0                         1659374411
# 10                        1851339485
# 13                        1437336070
# 14                        1083781983
# 29                        1427038199
# ...                              ...
# 986658                    1144384918
# 986659                    1316942584
# 986666                    1235359209
# 986674                    1124087143
# 986675                    1366635161
#
#        Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                             MAHR                       TODD
# 10                                        MEDHEKAR                     ANJALI
# 13                                   BOWERS-ZAMANI                     ALYSSA
# 14                                            DODD                      NANCY
# 29                                        KRUMHOLZ                      BARRY
# ...

# %%
df.drop(df[df["Entity Type of the Provider"] == 'o'].index, inplace = True)

# %%
df
# Out:
#         National Provider Identifier  \
# 0                         1659374411
# 10                        1851339485
# 13                        1437336070
# 14                        1083781983
# 29                        1427038199
# ...                              ...
# 986658                    1144384918
# 986659                    1316942584
# 986666                    1235359209
# 986674                    1124087143
# 986675                    1366635161
#
#        Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                             MAHR                       TODD
# 10                                        MEDHEKAR                     ANJALI
# 13                                   BOWERS-ZAMANI                     ALYSSA
# 14                                            DODD                      NANCY
# 29                                        KRUMHOLZ                      BARRY
# ...

# %%
l1 = df["Provider Type of the Provider"].unique()
print(li)
# Out:
# ['Allergists' 'Nurse Practitioner' 'Family Practice' 'Internal Medicine'
#  'Optometry' 'Physician Assistant' 'Psychiatrists' 'Orthopedic Surgery'
#  'Gynecologist' 'Pediatrician' 'Urologists' 'Radiation Oncology'
#  'Physical Therapist' 'Podiatrist' 'Dermatology' 'Emergency Medicine'
#  'General Practice' 'Neurologists' 'General surgeons' 'Rheumatologists'
#  'Chiropractic' 'Otolaryngologists' 'Infectious Disease'
#  'Endocrinologists' 'Centralized Flu' 'Ophthalmology' 'Anesthesiologists'
#  'Cardiology' 'Oral and maxillofacial surgeons' 'Oncologists'
#  'Radiologists' 'Gastroenterologists' 'CRNA' 'Orthopedic surgeons'
#  'Physical Medicine and Rehabilitation' 'Sports Medicine'
#  'Licensed Clinical Social Worker' 'Pathology'
#  'Mass Immunization Roster Biller' 'Addiction Medicine' 'Pain Management'
#  'Independent Diagnostic Testing Facility' 'Certified Nurse Midwife'
#  'Pulmonologists' 'Vascular Surgery' 'Certified Clinical Nurse Specialist'
# ...

# %%
l2=df["State Code of the Provider"].unique()

# %%
print(len(l1))
print(len(l2))
# Out:
# 21
# 59

# %%
dfnew=pd.DataFrame()
for speciality in l1:
    print(speciality)
    for state in l2:
        dfsubset=df[df["Provider Type of the Provider"]==speciality]
        dfsubset=dfsubset[dfsubset["State Code of the Provider"]==state]
        if len(dfsubset)>=100:
            dfsubset=dfsubset.sample(100)
        dfnew=dfnew.append(dfsubset, ignore_index=True)
# Out:
# Allergists
# Psychiatrists
# Gynecologist
# Pediatrician
# Urologists
# Podiatrist
# Neurologists
# General surgeons
# Rheumatologists
# Otolaryngologists
# Endocrinologists
# Anesthesiologists
# Oral and maxillofacial surgeons
# Oncologists
# Radiologists
# Gastroenterologists
# Orthopedic surgeons
# Pulmonologists
# Nephrologists
# Bariatrician
# Cardiac surgeons

# %%
dfnew
# Out:
#        National Provider Identifier  \
# 0                        1659374411
# 1                        1114999638
# 2                        1629118211
# 3                        1326299488
# 4                        1285800367
# ...                             ...
# 74941                    1346289618
# 74942                    1134174865
# 74943                    1649385451
# 74944                    1811985211
# 74945                    1902883747
#
#       Last Name/Organization Name of the Provider First Name of the Provider  \
# 0                                            MAHR                       TODD
# 1                                         CHUDNOW                    MELISSA
# 2                                         GONZAGA                  KATHERINE
# 3                                  THEODOROPOULOS                  DEMETRIOS
# 4                                        KONETZKI                      WAYNE
# ...

# %%
dfnew.to_csv (r'doctor_database.csv', index = False, header=True)
